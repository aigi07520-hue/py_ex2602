# %%
print("== 예제 1 ==")
s = "안녕하세요."
#   [0,1,2,3,4,5]

print("s길이 출력")
print(len(s))

# s[start:end(-1):step]
print("s를 이루는 문장 중에서 앞에 거 2개 출력")
print(s[0:2])

print("s를 이루는 문장 중에서 문자 하나 건너 뛰고 1개 출력")
print(s[1:2])

print("s를 이루는 문장 중에서 문자 4개 출력, 첫 인덱스 생략")
print(s[:4])

print("s를 이루는 문장 중에서 앞에 문자 3개 건너 뛰고, 나머지 전부 출력, len")
print(s[3:len(s)])

print("s를 이루는 문장 중에서 앞에 문자 3개 건너 뛰고, 뒤 인덱스 생략")
print(s[3:])
# Out:
# == 예제 1 ==
# s길이 출력
# 6
# s를 이루는 문장 중에서 앞에 거 2개 출력
# 안녕
# s를 이루는 문장 중에서 문자 하나 건너 뛰고 1개 출력
# 녕
# s를 이루는 문장 중에서 문자 4개 출력, 첫 인덱스 생략
# 안녕하세
# s를 이루는 문장 중에서 앞에 문자 3개 건너 뛰고, 나머지 전부 출력, len
# 세요.
# s를 이루는 문장 중에서 앞에 문자 3개 건너 뛰고, 뒤 인덱스 생략
# 세요.

# %%
print("== 예제 2 ==")
s = "안녕하세요."

print("s를 이루는 문자를 하나씩 출력, while")
i = 0
while i < len(s):
    print(s[i])
    i += 1

print("s를 이루는 문자를 역순으로 하나씩 출력, while")
i = len(s) - 1
while i >= 0:
    print(s[i])
    i -= 1

print("s를 이루는 문자를 하나씩 출력, for")
for c in s:
    print(c)
# Out:
# == 예제 2 ==
# s를 이루는 문자를 하나씩 출력, while
# 안
# 녕
# 하
# 세
# 요
# .
# s를 이루는 문자를 역순으로 하나씩 출력, while
# .
# 요
# 세
# 하
# 녕
# 안
# s를 이루는 문자를 하나씩 출력, for
# 안
# 녕
# 하
# 세
# 요
# .

# %%
print("== 예제 3 ==")
s = "a안b녕c하d세e요f"

print("s를 이루는 문장 중에서 한글만 출력")
print(s[1] + s[3] + s[5] + s[7] + s[9])

print("s를 이루는 문장 중에서 한글만 출력, for, if, or, continue, 방법 1")
for c in s:
    if c == 'a' or c == 'b' or c == 'c' or c == 'd' or c == 'e' or c == 'f':
        continue
    print(c)

print("s를 이루는 문장 중에서 한글만 출력, for, if, and, 방법 2")
for c in s:
    if c != 'a' and c != 'b' and c != 'c' and c != 'd' and c != 'e' and c != 'f':
        print(c)

print("s를 이루는 문장 중에서 한글만 출력, for, not in, 방법 3")
for c in s:
    if c not in ['a', 'b', 'c', 'd', 'e', 'f']:
        print(c)
# Out:
# == 예제 3 ==
# s를 이루는 문장 중에서 한글만 출력
# 안녕하세요
# s를 이루는 문장 중에서 한글만 출력, for, if, or, continue, 방법 1
# 안
# 녕
# 하
# 세
# 요
# s를 이루는 문장 중에서 한글만 출력, for, if, and, 방법 2
# 안
# 녕
# 하
# 세
# 요
# s를 이루는 문장 중에서 한글만 출력, for, not in, 방법 3
# 안
# 녕
# 하
# 세
# 요

# %%
class person():
 def _ init _(self):
       self,fello ='안녕하세요' 
 
   def hi(self):
     print(self.hello)
    
jin = person() 
jin.hi()

    

class person():
   def _ init _(self, name, age, hobby):
       self.fello ='안녕하세요' 
       self.name = NameError
       self.age = age
       self.hobby = hobby
   
    
   
  jin = person('진, 22, '운동')
  jin.introduce()


print("이름 :,'jin . name)
# Out:
#   File <string>:5
#     def hi(self):
#                  ^
# IndentationError: unindent does not match any outer indentation level

# %%
class person:
       pass
#빈종이 사람을 만듬 이름 정해줌

jin= person() #인스턴스 생성
jin.name = "진" #인스턴스를 생성한 뒤 속성 추가

print(jin.name)

paul =person()
print(paul.name)

# %%
#클래스 외부에서는 접근 불가, ㅋ믈래스 내부에서만 사용 가능한 private attrloute
class person():
   def _ init _(self, name, age, hobby):
       self.fello ='안녕하세요' 
       self.name = NameError
       self.age = age
       self.hobby = hobby


   def diet(sefl, loss_weight):
       self._weight -= ldss_weight
       print("몸무게 :",self._weight) 
        
jin = person('진', 22, '운동', 78)
jin._weight -=20
# Out:
#   Cell In[11], line 3
#     def _ init _(self, name, age, hobby):
#           ^
# SyntaxError: expected '('

# %%
class person():
    def_ㅐello(self):
       print('hello')
    
    def hi(self):
        self._hello()
jin =person()
jin
